# %%
# %matplotlib ipympl
import ipywidgets as widgets
import matplotlib.pyplot as plt

# %%
s = widgets.IntSlider()

# %%
display(s)
fig, ax = plt.subplots()

def on_value_change(change):
    x = change['new']
    ax.plot([x, x+1], [x**2, (x+1)**2])
    fig.canvas.draw()
    fig.canvas.flush_events()

    
s.observe(on_value_change, names='value')
# Out:
# IntSlider(value=42)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np

from mpl_toolkits.mplot3d import axes3d


fig = plt.figure()
ax = fig.add_subplot(projection='3d')

xs = np.linspace(-1, 1, 5)
ys = np.linspace(-1, 1, 5)
X, Y = np.meshgrid(xs, ys)
phi = 5
Z = np.cos(2 * np.pi * X + phi) * (1 - np.hypot(X, Y))

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=1, cstride=1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
xs, X, Z
# Out:
# (array([-1. , -0.5,  0. ,  0.5,  1. ]),
#  array([[-1. , -0.5,  0. ,  0.5,  1. ],
#         [-1. , -0.5,  0. ,  0.5,  1. ],
#         [-1. , -0.5,  0. ,  0.5,  1. ],
#         [-1. , -0.5,  0. ,  0.5,  1. ],
#         [-1. , -0.5,  0. ,  0.5,  1. ]]),
#  array([[-0.11749672,  0.03348178,  0.        ,  0.03348178, -0.11749672],
#         [-0.03348178, -0.08308273,  0.14183109, -0.08308273, -0.03348178],
#         [ 0.        , -0.14183109,  0.28366219, -0.14183109,  0.        ],
#         [-0.03348178, -0.08308273,  0.14183109, -0.08308273, -0.03348178],
#         [-0.11749672,  0.03348178,  0.        ,  0.03348178, -0.11749672]]))
